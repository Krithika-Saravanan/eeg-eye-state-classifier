# %%
import sys
import os

# %%
from src.load_data import load_edf

# %%
sys.path.append(os.path.abspath(".."))

# %%
from src.load_data import load_edf

# %%
import sys
print(sys.executable)

# %%
# %pip install mne

# %%
from src.load_data import load_edf

# %%
from src.load_data import load_edf

# %%
sys.path.append(os.path.abspath(".."))

# %%
import sys
import os

# %%
sys.path.append(os.path.abspath(".."))

# %%
from src.load_data import load_edf

# %%
import mne
print("MNE Works!")
# Out:
# MNE Works!

# %%
from src.load_data import load_edf

raw = load_edf("/Users/krithikasaravanan/data/S001R01.edf")
raw.plot(duration=5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.load_data import load_edf
#       3 raw = load_edf("/Users/krithikasaravanan/data/S001R01.edf")
#       4 raw.plot(duration=5)
#
# ModuleNotFoundError: No module named 'src'

# %%
import sys 
import os

# %%
sys.path.append(os.path.abspath(".."))

# %%
from src.load_data import load_edf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from src.load_data import load_edf
#
# ImportError: cannot import name 'load_edf' from 'src.load_data' (/Users/krithikasaravanan/Desktop/BCI/src/load_data.py)

# %%
import sys 
import os
sys.path.append(os.path.abspath(".."))

# %%
sys.path.append(os.path.abspath(".."))

# %%
from src.load_data import load_edf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from src.load_data import load_edf
#
# ImportError: cannot import name 'load_edf' from 'src.load_data' (/Users/krithikasaravanan/Desktop/BCI/src/load_data.py)

# %%
# %pip install pyEDFlib
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from src.load_data import load_edf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from src.load_data import load_edf
#
# ImportError: cannot import name 'load_edf' from 'src.load_data' (/Users/krithikasaravanan/Desktop/BCI/src/load_data.py)

# %%
from src.load_data import read_raw_edf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from src.load_data import read_raw_edf
#
# ImportError: cannot import name 'read_raw_edf' from 'src.load_data' (/Users/krithikasaravanan/Desktop/BCI/src/load_data.py)
